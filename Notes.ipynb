# %% [markdown]
# # Day 1

# %% [markdown]
# ## Print

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# I can initiate the RUN with shortcuts as well `Ctrl + ALT + Enter`

# %%
print("Hello World!)
# Out:
#   Cell In[3], line 1
#     print("Hello World!)
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# Error due to missing " -> there is a great indication with ^ symbol
# You can put the error message to Google.

# %% [markdown]
# There is a guide how to write Python code called: PEP [link](https://peps.python.org/pep-0008/)
# *It is a good practice to leave an empty line as a last line of the code

# %% [markdown]
# ## Challange 1
# Printing Practice
# Write a program that uses print statements to print the following recipe into the Output console. The text to print is already there, you just need to make it into code. Your code should print all five lines exactly the same as the example output below. Make sure that you don't change any of these existing text as everything, punctuation and casing all need to match!

# %% [markdown]
# 1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
# 2. Knead the dough for 10 minutes.
# 3. Add 3g of Salt.
# 4. Leave to rise for 2 hours.
# 5. Bake at 200 degrees C for 30 minutes.

# %%
print("1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.")
print("2. Knead the dough for 10 minutes.")
print("3. Add 3g of Salt.")
print("4. Leave to rise for 2 hours.")
print("5. Bake at 200 degrees C for 30 minutes.")
# Out:
# 1. Mix 500g of Flour, 10g Yeast and 300ml Water in a bowl.
# 2. Knead the dough for 10 minutes.
# 3. Add 3g of Salt.
# 4. Leave to rise for 2 hours.
# 5. Bake at 200 degrees C for 30 minutes.

# %% [markdown]
# ## String manipulation
#
# \n is a new line

# %%
print("Hello World!\nHello World!")
# Out:
# Hello World!
# Hello World!

# %% [markdown]
# We can also concat multipe variables togather with +
# But be sure to add SPACE

# %%
print("Hello" + "Angela")
print("Hello " + "Angela")
print("Hello" + " " + "Angela")
# Out:
# HelloAngela
# Hello Angela
# Hello Angela

# %% [markdown]
# ## Debugging

# %% [markdown]
# ### Challange 3
# Debugging Practice
# Look at the code in the code editor. There are errors on all 5 lines of code. Fix the code so that it runs without errors.
#
# Try to run the code and debug each line using the error messages and feedback.

# %%
# Fix the code below 👇
print(Notes from Day 1")
 print("The print statement is used to output strings")
print("Strings are strings of characters"
priint("String Concatenation is done with the + sign")
print(("New lines can be created with a \ and the letter n")
# Out:
#   Cell In[6], line 2
#     print(Notes from Day 1")
#                           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
print("Notes from Day 1")
print("The print statement is used to output strings")
print("Strings are strings of characters")
print("String Concatenation is done with the + sign")
print("New lines can be created with a \ and the letter n")
# Out:
# Notes from Day 1
# The print statement is used to output strings
# Strings are strings of characters
# String Concatenation is done with the + sign
# New lines can be created with a \ and the letter n
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# <>:5: SyntaxWarning: invalid escape sequence '\ '
# /tmp/ipykernel_1973/2192619333.py:5: SyntaxWarning: invalid escape sequence '\ '
#   print("New lines can be created with a \ and the letter n")

# %% [markdown]
# ## Input function

# %% [markdown]
# It is used to get input from the user.
# Called: "Input"
# I can add an answer. Until it it hit an enter, the code is running.
#
# If we combine the print and input, that it is nested inside, so the asnwer can be printed dynamicly.
#
# The # symbol is used for comments in Python.

# %%
#input("What is your name?")

print("Hello " + input("What is your name?") + "!")
# Out:
# Hello Pali!

# %% [markdown]
# ## Variables

# %% [markdown]
# = sign assigns the input function's added for later use.
# So we can recall the data based on its name

# %%
name = input("What is your name")
print(name)

# %% [markdown]
# Important to search for functions that are there. w3school.com/python is a really great website to search for information on the functions.
# We will use eg. len function to determine how much letter is in an input from the user.

# %%
print(len(input("What is your name?")))
# Out:
# 4

# %%
username = input("What is your name?")
length = len(username)
print(length)
# Out:
# 4

# %% [markdown]
# ## Challange 3

# %% [markdown]
# We have 2 variables glass1 and glass2. glass1 contains milk and glass2 contains juice. Write 3 lines of code to switch the contents of the variables. You are not allowed to type the words "milk" or "juice". You are only allowed to use variables to solve this exercise.

# %%
glass1 = "milk"
glass2 = "juice"

# %%
glass1 = "milk"
glass2 = "juice"

temp = glass1
glass1 = glass2
glass2 = temp

# %% [markdown]
# ## Naming variables

# %% [markdown]
# Make your code readable - that coming back after months, you will know and recognize.
# You can only use single word, but you can overcome with a _
# You can use number + betu combination as well
# But need to be consistent of the variables across the code.
# The function names are restricted, not to be used
